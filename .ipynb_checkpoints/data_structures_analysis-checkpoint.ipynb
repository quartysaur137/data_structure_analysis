# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.category import UnitData

# %%
def filter_to_decrease_labels(years, array, labels):
    new_years = []
    new_array = []
    
    curr_lowest = len(labels)
    for i, item in enumerate(array):
        idx = labels.index(item)
        if idx < curr_lowest:
            new_years.append(years[i])
            new_array.append(item)
            curr_lowest = idx
            
    return new_years, new_array

def filter_to_decrease_nums(years, array):
    new_years = []
    new_array = []
    
    curr_lowest = float('inf')
    for i, num in enumerate(array):
        if num < curr_lowest:
            new_years.append(years[i])
            new_array.append(num)
            curr_lowest = num
            
    return new_years, new_array

# %%
def add_rows_for_algo(df, row, idx):
    """
    If an algo has multiple variations (delimiter is '; '), split its row into multiple rows
    """
    df = df.drop([idx])
    vars = row['Variation'].split('; ')
    for var in vars:
        copy = row.copy(deep=True)
        copy['Variation'] = var
        df = pd.concat([df, copy.to_frame().T], ignore_index=True)
    return df

# %%
# pd.read_csv('Analysis/datastructures_dirty_8-9.csv')

# %%
def clean_data():
    """
    Go through data.csv and if any algos have multiple variations, rewrite data.csv with the algo split into multiple rows.
    Get rid of trailing ?'s in the complexity class columns.
    """
    dataframe = pd.read_csv('Analysis/datastructures_dirty.csv')
    dataframe = dataframe.replace(np.nan, '', regex=True)
#     dataframe = dataframe.drop('Domain', axis=1)
#     dataframe = dataframe.rename(columns={"Domain.1": "Domain"})
    
    dataframe = dataframe[
#                           (dataframe['Time Complexity Class'] != '#VALUE!') &
#                           (dataframe['Space Complexity Class'] != '#VALUE!') &
                          (dataframe["Looked at?"] != 0.001) &
                          (dataframe["Looked at?"] != 0.0) &
                          (dataframe["Year"] != "?") &
                          (dataframe["Year"] != "")
#                           (dataframe["Exact Problem Statement?"] == 1)
                        ]

    # Get rid of parallel, quantum, and approximate algorithms
#     dataframe = dataframe[(dataframe["Quantum?"] == 0) | (dataframe["Quantum?"] == "0")]
#     dataframe = dataframe[(dataframe["Parallel?"] == 0) | (dataframe["Parallel?"] == "0")]
#     dataframe = dataframe[(dataframe["Approximate?"] == 0) | (dataframe["Approximate?"] == "0")]


    dataframe.to_csv('Analysis/datastructures.csv')
    return dataframe

# %%
data = clean_data()

# %% [markdown]
# # Generate graphs for all data structures

# %%
def is_op(class_array):
    for item in class_array:
        if type(item) is not float and type(item) is not int:
            return False
    return True

# %%
def generate_stacked_graph(domain_name):
    ds = data[data["Domain"] == domain_name]
    ds = ds.sort_values("Year")
    
    years = list(ds["Year"])
    for i, val in enumerate(years):
        years[i] = int(val)
        
    # Space, Build, Insert, Delete, Find, Successor/Predecessor, Union, Min/Max, Increase-Key/Update
    # Push, Pop Most Recent, Pop Oldest, Nearest Neighbor, Range Search, Query
    space = list(ds["Space Class"])
    build = list(ds["Build Runtime Class"])
    insert = list(ds["Insert Runtime Class"])
    delete = list(ds["Delete Runtime Class"])
    find = list(ds["Find Runtime Class"])
    successor = list(ds["Successor/Predecessor Runtime Class"])
    union = list(ds["Union Runtime Class"])
    minmax = list(ds["Min/Max Runtime Class"])
    update = list(ds["Increase-Key/Update Runtime Class"])
    push = list(ds["Push Runtime Class"])
    poprecent = list(ds["Pop Most Recent Runtime Class"])
    popoldest = list(ds["Pop Oldest Runtime Class"])
    neighbor = list(ds["Nearest Neighbor Runtime Class"])
    search = list(ds["Range Search Runtime Class"])
    query = list(ds["Query Runtime Class"])
    
    op_count = 0
    
    if is_op(space):
        years_space, space_filtered = filter_to_decrease_nums(years, space)
        op_count += 1
    if is_op(build):
        years_build, build_filtered = filter_to_decrease_nums(years, build)
        op_count += 1
    if is_op(insert):
        years_insert, insert_filtered = filter_to_decrease_nums(years, insert)
        op_count += 1
    if is_op(delete):
        years_delete, delete_filtered = filter_to_decrease_nums(years, delete)
        op_count += 1
    if is_op(find):
        years_find, find_filtered = filter_to_decrease_nums(years, find)
        op_count += 1
    if is_op(successor):
        years_successor, successor_filtered = filter_to_decrease_nums(years, successor)
        op_count += 1
    if is_op(union):
        years_union, union_filtered = filter_to_decrease_nums(years, union)
        op_count += 1
    if is_op(minmax):
        years_minmax, minmax_filtered = filter_to_decrease_nums(years, minmax)
        op_count += 1
    if is_op(update):
        years_update, update_filtered = filter_to_decrease_nums(years, update)
        op_count += 1
    if is_op(push):
        years_push, push_filtered = filter_to_decrease_nums(years, push)
        op_count += 1
    if is_op(poprecent):
        years_poprecent, poprecent_filtered = filter_to_decrease_nums(years, poprecent)
        op_count += 1
    if is_op(popoldest):
        years_popoldest, popoldest_filtered = filter_to_decrease_nums(years, popoldest)
        op_count += 1
    if is_op(neighbor):
        years_neighbor, neighbor_filtered = filter_to_decrease_nums(years, neighbor)
        op_count += 1
    if is_op(search):
        years_search, search_filtered = filter_to_decrease_nums(years, search)
        op_count += 1
    if is_op(query):
        years_query, query_filtered = filter_to_decrease_nums(years, query)
        op_count += 1
    
    fig, ax = plt.subplots(op_count, 1, figsize=(9, 8), sharex=True)
    colors = ["g", "b", "r", "y", "orange", "purple", "c", "salmon", "olive", "sienna",
              "deeppink", "slategrey", "yellowgreen", "teal", "maroon"]
    
    curr_ax = 0
    if is_op(space):
        ax[curr_ax].scatter(years, space, color=colors[0])
        ax[curr_ax].plot(years_space+[2100], space_filtered+[space[-1]], drawstyle='steps-post', color=colors[0])
        ax[curr_ax].legend(["Space"])
        curr_ax += 1
    if is_op(build):
        ax[curr_ax].scatter(years, build, color=colors[1])
        ax[curr_ax].plot(years_build+[2100], build_filtered+[build[-1]], drawstyle='steps-post', color=colors[1])
        ax[curr_ax].legend(["Build"])
        curr_ax += 1
    if is_op(insert):
        ax[curr_ax].scatter(years, insert, color=colors[2])
        ax[curr_ax].plot(years_insert+[2100], insert_filtered+[insert[-1]], drawstyle='steps-post', color=colors[2])
        ax[curr_ax].legend(["Insert"])
        curr_ax += 1
    if is_op(delete):
        ax[curr_ax].scatter(years, delete, color=colors[3])
        ax[curr_ax].plot(years_delete+[2100], delete_filtered+[delete[-1]], drawstyle='steps-post', color=colors[3])
        ax[curr_ax].legend(["Delete"])
        curr_ax += 1
    if is_op(find):
        ax[curr_ax].scatter(years, find, color=colors[4])
        ax[curr_ax].plot(years_find+[2100], find_filtered+[find[-1]], drawstyle='steps-post', color=colors[4])
        ax[curr_ax].legend(["Find"])
        curr_ax += 1
    if is_op(successor):
        ax[curr_ax].scatter(years, successor, color=colors[5])
        ax[curr_ax].plot(years_successor+[2100], successor_filtered+[successor[-1]], drawstyle='steps-post', color=colors[5])
        ax[curr_ax].legend(["Successor/Predecessor"])
        curr_ax += 1
    if is_op(union):
        ax[curr_ax].scatter(years, union, color=colors[6])
        ax[curr_ax].plot(years_union+[2100], union_filtered+[union[-1]], drawstyle='steps-post', color=colors[6])
        ax[curr_ax].legend(["Union"])
        curr_ax += 1
    if is_op(minmax):
        ax[curr_ax].scatter(years, minmax, color=colors[7])
        ax[curr_ax].plot(years_minmax+[2100], minmax_filtered+[minmax[-1]], drawstyle='steps-post', color=colors[7])
        ax[curr_ax].legend(["Min/Max"])
        curr_ax += 1
    if is_op(update):
        ax[curr_ax].scatter(years, update, color=colors[8])
        ax[curr_ax].plot(years_update+[2100], update_filtered+[update[-1]], drawstyle='steps-post', color=colors[8])
        ax[curr_ax].legend(["Increase-Key/Update"])
        curr_ax += 1
    if is_op(push):
        ax[curr_ax].scatter(years, push, color=colors[9])
        ax[curr_ax].plot(years_push+[2100], push_filtered+[push[-1]], drawstyle='steps-post', color=colors[9])
        ax[curr_ax].legend(["Push"])
        curr_ax += 1
    if is_op(poprecent):
        ax[curr_ax].scatter(years, poprecent, color=colors[10])
        ax[curr_ax].plot(years_poprecent+[2100], poprecent_filtered+[poprecent[-1]], drawstyle='steps-post', color=colors[10])
        ax[curr_ax].legend(["Pop Most Recent"])
        curr_ax += 1
    if is_op(popoldest):
        ax[curr_ax].scatter(years, popoldest, color=colors[11])
        ax[curr_ax].plot(years_popoldest+[2100], popoldest_filtered+[popoldest[-1]], drawstyle='steps-post', color=colors[11])
        ax[curr_ax].legend(["Pop Oldest"])
        curr_ax += 1
    if is_op(neighbor):
        ax[curr_ax].scatter(years, neighbor, color=colors[12])
        ax[curr_ax].plot(years_neighbor+[2100], neighbor_filtered+[neighbor[-1]], drawstyle='steps-post', color=colors[12])
        ax[curr_ax].legend(["Nearest Neighbor"])
        curr_ax += 1
    if is_op(search):
        ax[curr_ax].scatter(years, search, color=colors[13])
        ax[curr_ax].plot(years_search+[2100], search_filtered+[search[-1]], drawstyle='steps-post', color=colors[13])
        ax[curr_ax].legend(["Range Search"])
        curr_ax += 1
    if is_op(query):
        ax[curr_ax].scatter(years, query, color=colors[14])
        ax[curr_ax].plot(years_query+[2100], query_filtered+[query[-1]], drawstyle='steps-post', color=colors[14])
        ax[curr_ax].legend(["Query"])
        curr_ax += 1
    
    ax[0].set_title(domain_name)
    ax[curr_ax-1].set_xlabel("Year")
    fig.text(0.06, 0.5, 'Complexity Class', ha='center', va='center', rotation='vertical')
    plt.xlim(years[0]-2, 2023)
    plt.savefig("stacked_graphs/" + domain_name.replace("/", "-")) 
    plt.show()

# %%
for ds in set(data["Domain"]):
    generate_stacked_graph(ds)

# %% [markdown]
# ## Unordered Associative Array

# %%
associative_array = data[data["Domain"] == "Unordered Associative Array"]
associative_array = associative_array.sort_values("Year")

associative_array = associative_array[[
    "Year", 
    "Datastructure", 
    "Space", "Space Class",
    "Build (Time)", "Build Runtime Class", "Build Notes (constants, amortized?, randomized?, etc.)", 
    "Insert (Time)", "Insert Runtime Class", "Insert Notes (constants, amortized?, randomized?, etc.)",
    "Delete (Time)", "Delete Runtime Class", "Delete Notes (constants, amortized?, randomized?, etc.)", 
    "Find (Time)", "Find Runtime Class", "Find Notes (constants, amortized?, randomized?, etc.)", 
   ]]

# %%
associative_array

# %%
aa_years = list(associative_array["Year"])
for i, val in enumerate(aa_years):
    aa_years[i] = int(val)

# %%
aa_space = list(associative_array["Space"])
aa_build_time = list(associative_array["Build (Time)"])
aa_insert_time = list(associative_array["Insert (Time)"])
aa_delete_time = list(associative_array["Delete (Time)"])
aa_find_time = list(associative_array["Find (Time)"])

aa_space_class = list(associative_array["Space Class"])
aa_build_class = list(associative_array["Build Runtime Class"])
aa_insert_class = list(associative_array["Insert Runtime Class"])
aa_delete_class = list(associative_array["Delete Runtime Class"])
aa_find_class = list(associative_array["Find Runtime Class"])

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 7))

space_labels = ["(1+o(1))n", "O(n)", "O(n+m)"]
insert_labels = ["O(1)", "O(lg (n/m))"]
delete_labels = ["O(1)", "O(lg (n/m))", "O(n/m)"]
find_labels = ["O(1)", "O(lg (n/m))", "O(n/m)"]

ax[0,0].scatter(aa_years, aa_space, yunits=UnitData(space_labels))
ax[0,1].scatter(aa_years, aa_insert_time, yunits=UnitData(insert_labels))
ax[1,0].scatter(aa_years, aa_delete_time, yunits=UnitData(delete_labels))
ax[1,1].scatter(aa_years, aa_find_time, yunits=UnitData(find_labels))

ax[0,0].set_title("Associative Array Space")
ax[0,1].set_title("Associative Array Insert Time")
ax[1,0].set_title("Associative Array Delete Time")
ax[1,1].set_title("Associative Array Find Time")

for i in range(2):
    for j in range(2):
        ax[i,j].set_xlabel("Year")
        ax[i,j].set_ylabel("Complexity")
           
plt.tight_layout(pad=1.5)
plt.show()

# %%
plt.scatter(aa_years, aa_insert_time, yunits=UnitData(insert_labels), s=95, color="b")
plt.scatter(aa_years, aa_delete_time, yunits=UnitData(delete_labels), s=50, color="r")
plt.scatter(aa_years, aa_find_time, yunits=UnitData(find_labels), s=15, color="y")

plt.legend([
            "Insert Time", 
            "Delete Time",
            "Find Time"
           ], bbox_to_anchor=(1.0, 1.0))

plt.title("Associative Array")
plt.xlabel("Year")
plt.ylabel("Complexity")
plt.show()

# %% [markdown]
# ### stacked graphs

# %%
space_labels = ["(1+o(1))n", "O(n)", "O(n+m)"]
insert_labels = ["O(1)", "O(lg (n/m))"]
delete_labels = ["O(1)", "O(lg (n/m))", "O(n/m)"]
find_labels = ["O(1)", "O(lg (n/m))", "O(n/m)"]

aa_years_space, aa_space_filtered = filter_to_decrease_labels(aa_years, aa_space, space_labels)
aa_years_insert, aa_insert_filtered = filter_to_decrease_labels(aa_years, aa_insert_time, insert_labels)
aa_years_delete, aa_delete_filtered = filter_to_decrease_labels(aa_years, aa_delete_time, delete_labels)
aa_years_find, aa_find_filtered = filter_to_decrease_labels(aa_years, aa_find_time, find_labels)

aa_years_space_class, aa_space_class_filtered = filter_to_decrease_nums(aa_years, aa_space_class)
aa_years_insert_class, aa_insert_class_filtered = filter_to_decrease_nums(aa_years, aa_insert_class)
aa_years_delete_class, aa_delete_class_filtered = filter_to_decrease_nums(aa_years, aa_delete_class)
aa_years_find_class, aa_find_class_filtered = filter_to_decrease_nums(aa_years, aa_find_class)

# %%
fig, ax = plt.subplots(4, 1, figsize=(8, 7), sharex=True)

ax[0].scatter(aa_years, aa_space, yunits=UnitData(space_labels), color="g")
ax[1].scatter(aa_years, aa_insert_time, yunits=UnitData(insert_labels), color="b")
ax[2].scatter(aa_years, aa_delete_time, yunits=UnitData(delete_labels), color="r")
ax[3].scatter(aa_years, aa_find_time, yunits=UnitData(find_labels), color="y")

ax[0].plot(aa_years_space+[2100], aa_space_filtered+[space_labels[0]], drawstyle='steps-post', color="g")
ax[1].plot(aa_years_insert+[2100], aa_insert_filtered+[insert_labels[0]], drawstyle='steps-post', color="b")
ax[2].plot(aa_years_delete+[2100], aa_delete_filtered+[delete_labels[0]], drawstyle='steps-post', color="r")
ax[3].plot(aa_years_find+[2100], aa_find_filtered+[find_labels[0]], drawstyle='steps-post', color="y")

ax[0].legend(["Space"])
ax[1].legend(["Insert"])
ax[2].legend(["Delete"])
ax[3].legend(["Find"])

ax[0].set_title("Associative Array")
ax[3].set_xlabel("Year")
fig.text(0.0, 0.5, 'Complexity', ha='center', va='center', rotation='vertical')
plt.xlim(aa_years[0]-2, aa_years[-1]+5)
plt.show()


fig, ax = plt.subplots(4, 1, figsize=(8, 7), sharex=True)

ax[0].scatter(aa_years, aa_space_class, color="g")
ax[1].scatter(aa_years, aa_insert_class, color="b")
ax[2].scatter(aa_years, aa_delete_class, color="r")
ax[3].scatter(aa_years, aa_find_class, color="y")

ax[0].plot(aa_years_space_class+[2100], aa_space_class_filtered+[aa_space_class[-1]], 
           drawstyle='steps-post', color="g")
ax[1].plot(aa_years_insert_class+[2100], aa_insert_class_filtered+[aa_insert_class[-1]], 
           drawstyle='steps-post', color="b")
ax[2].plot(aa_years_delete_class+[2100], aa_delete_class_filtered+[aa_delete_class[-1]], 
           drawstyle='steps-post', color="r")
ax[3].plot(aa_years_find_class+[2100], aa_find_class_filtered+[aa_find_class[-1]], 
           drawstyle='steps-post', color="y")

ax[0].legend(["Space"])
ax[1].legend(["Insert"])
ax[2].legend(["Delete"])
ax[3].legend(["Find"])

ax[0].set_title("Associative Array")
ax[3].set_xlabel("Year")
fig.text(0.06, 0.5, 'Complexity Class', ha='center', va='center', rotation='vertical')
plt.xlim(aa_years[0]-2, aa_years[-1]+5)
plt.show()

# %%
plt.scatter(aa_years, [num+0.1 for num in aa_insert_class])
plt.scatter(aa_years, aa_delete_class)
plt.scatter(aa_years, [num-0.1 for num in aa_find_class])

plt.legend([
            "Insert Time", 
            "Delete Time",
            "Find Time"
           ], bbox_to_anchor=(1.0, 1.0))

plt.title("Associative Array")
plt.xlabel("Year")
plt.ylabel("Complexity")
plt.show()

# %% [markdown]
# ## Priority Queue

# %%
priority_queue = data[data["Domain"] == "Priority Queue"]
priority_queue = priority_queue.sort_values("Year")

priority_queue = priority_queue[[
    "Year", 
    "Datastructure", 
    "Space", "Space Class", 
    "Build (Time)", "Build Runtime Class", #"Build Notes (constants, amortized?, randomized?, etc.)", 
    "Insert (Time)", "Insert Runtime Class", #"Insert Notes (constants, amortized?, randomized?, etc.)",
    "Delete (Time)", "Delete Runtime Class", #"Delete Notes (constants, amortized?, randomized?, etc.)", 
    "Union (Time)", "Union Runtime Class", #"Union Notes (constants, amortized?, randomized?, etc.)", 
    "Min/Max (Time)", "Min/Max Runtime Class", #"Min/Max Notes (constants, amortized?, randomized?, etc.)", 
    "Increase-Key/Update (Time)", "Increase-Key/Update Runtime Class", #"Increase-Key/Update Notes (constants, amortized?, randomized?, etc.)", 
   ]]

# %%
priority_queue
# Out:
#      Year                   Datastructure         Space Space Class  \
# 82   1964                     Binary Heap          O(n)         6.0
# 84   1972      Height-biased Leftist Heap          O(n)         6.0
# 83   1975                      d-ary Heap          O(n)         6.0
# 86   1978                   Binomial Heap          O(n)         6.0
# 109  1980                            Beap      n + O(1)         6.0
# 120  1981                   Leonardo Heap          O(n)         6.0
# 103  1986             Bottom-Up Skew Heap         O(n)?         6.0
# 90   1986                    Pairing Heap          O(n)         6.0
# 102  1986              Top-Down Skew Heap         O(n)?         6.0
# 87   1987                  Fibonacci Heap          O(n)         6.0
# 88   1988               Rank-Relaxed Heap          O(n)         6.0
# 89   1988                Run-Relaxed Heap          O(n)         6.0
# 111  1993                        K-D heap        O_k(n)         6.0
# 104  1993                       Weak Heap          O(n)         6.0
# 118  1995            (a,b) Priority Queue          O(n)         6.0
# 117  1995              AVL Priority Queue          O(n)         6.0
# 116  1995         One-Step Priority Queue          O(n)         6.0
# 115  1995        Red-Black Priority Queue          O(n)         6.0
# 92   1996                     Brodal Heap          O(n)         6.0
# 85   1998      Weight-biased Leftist Heap          O(n)         6.0
# 112  1998        Randomized Meldable Heap          O(n)         6.0
# 98   1999                       Thin Heap         O(n)?         6.0
# 99   1999                        Fat Heap         O(n)?         6.0
# 119  1999                        2-3 Heap         O(n)?         6.0
# 101  2000                  Trinomial Heap         O(n)?         6.0
# 114  2000                     Shadow Heap         O(n)?         6.0
# 113  2000                       Soft Heap          O(n)         6.0
# 100  2008                      Thick Heap         O(n)?         6.0
# 93   2009          One-Pass Binomial Heap          O(n)         6.0
# 94   2009               Rank-Pairing Heap          O(n)         6.0
# 97   2010                  Violation Heap         O(n)?         6.0
# 110  2010                          B-heap          O(n)         6.0
# 107  2012          Rank-Relaxed Weak Heap  4n + O(lg n)         6.0
# 105  2012  Weak Heap with Bulk Insertions          O(n)         6.0
# 95   2012           Strict Fibonacci Heap          O(n)         6.0
# 106  2012           Run-Relaxed Weak Heap          O(n)         6.0
# 96   2013                      Quake Heap         O(n)?         6.0
# 91   2017             Pairing Heap (lazy)          O(n)         6.0
#
#                  Build (Time) Build Runtime Class            Insert (Time)  \
# 82                       O(n)                 6.0                  O(lg n)
# 84                       O(n)                 6.0                  O(lg n)
# 83        O((n lg n)/(lg d))?                 7.0         O((lg n)/(lg d))
# 86                       O(n)                 6.0                     O(1)
# 109                 O(n lg n)                 7.0               O(sqrt(n))
# 120                     O(n)?                 6.0                  O(lg n)
# 103                      O(n)                 6.0                     O(1)
# 90                       O(n)                 6.0   O(2^(2*sqrt(lg lg n)))
# 102                      O(n)                 6.0                  O(lg n)
# 87                       O(n)                 6.0                     O(1)
# 88                       O(n)                 6.0                     O(1)
# 89                       O(n)                 6.0                     O(1)
# 111                    O_k(n)                 6.0                O_k(lg n)
# 104                      O(n)                 6.0                  O(lg n)
# 118                      O(n)                 6.0                     O(1)
# 117                      O(n)                 6.0                     O(1)
# 116                      O(n)                 6.0                     O(1)
# 115                      O(n)                 6.0                     O(1)
# 92                       O(n)                 6.0                     O(1)
# 85                       O(n)                 6.0                  O(lg n)
# 112                      O(n)                 6.0                  O(lg n)
# 98                       O(n)                 6.0                     O(1)
# 99                       O(n)                 6.0                     O(1)
# 119                     O(n)?                 6.0                     O(1)
# 101                      O(n)                 6.0                     O(1)
# 114  O(n(lg n)(lg lg n)/f(n))                6.01  O((lg n)(lg lg n)/f(n))
# 113            O(n lg(1/eps))                 6.0             O(lg(1/eps))
# 100                     O(n)?                 6.0                    O(1)?
# 93                       O(n)                 6.0                     O(1)
# 94                       O(n)                 6.0                     O(1)
# 97                       O(n)                 6.0                     O(1)
# 110                      O(n)                 6.0                  O(lg n)
# 107                      O(n)                 6.0                     O(1)
# 105                      O(n)                 6.0                     O(1)
# 95                       O(n)                 6.0                     O(1)
# 106                      O(n)                 6.0                     O(1)
# 96                       O(n)                 6.0                     O(1)
# 91                       O(n)                 6.0                     O(1)
#
#     Insert Runtime Class       Delete (Time) Delete Runtime Class  \
# 82                   3.0             O(lg n)                  3.0
# 84                   3.0             O(lg n)                  3.0
# 83                   3.0  O((d lg n)/(lg d))                  3.0
# 86                   1.0             O(lg n)                  3.0
# 109                  5.0          O(sqrt(n))                  5.0
# 120                  3.0             O(lg n)                  3.0
# 103                  1.0             O(lg n)                  3.0
# 90                  2.95             O(lg n)                  3.0
# 102                  3.0             O(lg n)                  3.0
# 87                   1.0             O(lg n)                  3.0
# 88                   1.0             O(lg n)                  3.0
# 89                   1.0             O(lg n)                  3.0
# 111                  3.0           O_k(lg n)                  3.0
# 104                  3.0             O(lg n)                  3.0
# 118                  1.0             O(lg n)                  3.0
# 117                  1.0             O(lg n)                  3.0
# 116                  1.0             O(lg n)                  3.0
# 115                  1.0             O(lg n)                  3.0
# 92                   1.0             O(lg n)                  3.0
# 85                   3.0             O(lg n)                  3.0
# 112                  3.0             O(lg n)                  3.0
# 98                   1.0             O(lg n)                  3.0
# 99                   1.0             O(lg n)                  3.0
# 119                  1.0             O(lg n)                  3.0
# 101                  1.0             O(lg n)                  3.0
# 114                  1.5             O(f(n))                 3.01
# 113                  1.0                O(1)                  1.0
# 100                  1.0             O(lg n)                  3.0
# 93                   1.0             O(lg n)                  3.0
# 94                   1.0             O(lg n)                  3.0
# 97                   1.0             O(lg n)                  3.0
# 110                  3.0             O(lg n)                  3.0
# 107                  1.0             O(lg n)                  3.0
# 105                  1.0             O(lg n)                  3.0
# 95                   1.0             O(lg n)                  3.0
# 106                  1.0             O(lg n)                  3.0
# 96                   1.0             O(lg n)                  3.0
# 91                   1.0             O(lg n)                  3.0
#
#                Union (Time) Union Runtime Class Min/Max (Time)  \
# 82                     O(n)                 6.0           O(1)
# 84                  O(lg n)                 3.0           O(1)
# 83                    O(n)?                 6.0           O(1)
# 86                  O(lg n)                 3.0           O(1)
# 109              O(n lg n)?                 7.0           O(1)
# 120              O(n lg n)?                 7.0           O(1)
# 103                    O(1)                 1.0           O(1)
# 90   O(2^(2*sqrt(lg lg n)))                2.95           O(1)
# 102                 O(lg n)                 3.0           O(1)
# 87                     O(1)                 1.0           O(1)
# 88                     O(1)                 1.0        O(lg n)
# 89                 O(lg n)?                 3.0        O(lg n)
# 111               O_k(lg n)                 3.0         O_k(1)
# 104                    O(1)                 1.0           O(1)
# 118                    O(1)                 1.0           O(1)
# 117                    O(1)                 1.0           O(1)
# 116                    O(1)                 1.0           O(1)
# 115                    O(1)                 1.0           O(1)
# 92                     O(1)                 1.0           O(1)
# 85                  O(lg n)                 3.0           O(1)
# 112                 O(lg n)                 3.0           O(1)
# 98                     O(1)                 1.0           O(1)
# 99                  O(lg n)                 3.0        O(lg n)
# 119                   O(n)?                 6.0       O(lg n)?
# 101               O(lg n)??                 3.0           O(1)
# 114               O(n*f(n))                7.01        O(f(n))
# 113                    O(1)                 1.0           O(1)
# 100                   O(1)?                 1.0           O(1)
# 93                     O(1)                 1.0           O(1)
# 94                     O(1)                 1.0           O(1)
# 97                     O(1)                 1.0           O(1)
# 110                    O(n)                 6.0           O(1)
# 107                    O(1)                 1.0          O(1)?
# 105                    O(1)                 1.0           O(1)
# 95                     O(1)                 1.0           O(1)
# 106                    O(1)                 1.0          O(1)?
# 96                     O(1)                 1.0           O(1)
# 91               O(lg lg n)                 2.0           O(1)
#
#     Min/Max Runtime Class Increase-Key/Update (Time)  \
# 82                    1.0                    O(lg n)
# 84                    1.0                    O(lg n)
# 83                    1.0           O((lg n)/(lg d))
# 86                    1.0                    O(lg n)
# 109                   1.0                O(sqrt(n))?
# 120                   1.0                    O(lg n)
# 103                   1.0                   O(lg n)?
# 90                    1.0     O(2^(2*sqrt(lg lg n)))
# 102                   1.0                   O(lg n)?
# 87                    1.0                       O(1)
# 88                    3.0                       O(1)
# 89                    3.0                       O(1)
# 111                   1.0                  O_k(lg n)
# 104                   1.0                    O(lg n)
# 118                   1.0                       O(1)
# 117                   1.0                       O(1)
# 116                   1.0                       O(1)
# 115                   1.0                       O(1)
# 92                    1.0                       O(1)
# 85                    1.0                      O(n)?
# 112                   1.0                    O(lg n)
# 98                    1.0                       O(1)
# 99                    3.0                       O(1)
# 119                   3.0                       O(1)
# 101                   1.0                       O(1)
# 114                  3.01                    O(f(n))
# 113                   1.0               O(lg(1/eps))
# 100                   1.0                      O(1)?
# 93                    1.0                   O(lg n)?
# 94                    1.0                       O(1)
# 97                    1.0                       O(1)
# 110                   1.0                    O(lg n)
# 107                   1.0                       O(1)
# 105                   1.0                   O(lg n)?
# 95                    1.0                       O(1)
# 106                   1.0                       O(1)
# 96                    1.0                       O(1)
# 91                    1.0                 O(lg lg n)
#
#     Increase-Key/Update Runtime Class
# 82                                3.0
# 84                                3.0
# 83                                3.0
# 86                                3.0
# 109                               5.0
# 120                               3.0
# 103                               3.0
# 90                               2.95
# 102                               3.0
# 87                                1.0
# 88                                1.0
# 89                                1.0
# 111                               3.0
# 104                               3.0
# 118                               1.0
# 117                               1.0
# 116                               1.0
# 115                               1.0
# 92                                1.0
# 85                                6.0
# 112                               3.0
# 98                                1.0
# 99                                1.0
# 119                               1.0
# 101                               1.0
# 114                              3.01
# 113                               1.0
# 100                               1.0
# 93                                3.0
# 94                                1.0
# 97                                1.0
# 110                               3.0
# 107                               1.0
# 105                               3.0
# 95                                1.0
# 106                               1.0
# 96                                1.0
# 91                                2.0

# %%
# priority_queue.loc[47]["Parameters"]

# %%
pq_years = list(priority_queue["Year"])
for i, val in enumerate(pq_years):
    pq_years[i] = int(val)

# %%
pq_build_time = priority_queue["Build (Time)"]
pq_insert_time = priority_queue["Insert (Time)"]
pq_delete_time = priority_queue["Delete (Time)"]
pq_union_time = priority_queue["Union (Time)"]
pq_minmax_time = priority_queue["Min/Max (Time)"]
pq_update_time = priority_queue["Increase-Key/Update (Time)"]

pq_build_class = list(priority_queue["Build Runtime Class"])
pq_insert_class = list(priority_queue["Insert Runtime Class"])
pq_delete_class = list(priority_queue["Delete Runtime Class"])
pq_union_class = list(priority_queue["Union Runtime Class"])
pq_minmax_class = list(priority_queue["Min/Max Runtime Class"])
pq_update_class = list(priority_queue["Increase-Key/Update Runtime Class"])

# %%
pq_years_build_class, pq_build_class_filtered = filter_to_decrease_nums(pq_years, pq_build_class)
pq_years_insert_class, pq_insert_class_filtered = filter_to_decrease_nums(pq_years, pq_insert_class)
pq_years_delete_class, pq_delete_class_filtered = filter_to_decrease_nums(pq_years, pq_delete_class)
pq_years_union_class, pq_union_class_filtered = filter_to_decrease_nums(pq_years, pq_union_class)
pq_years_minmax_class, pq_minmax_class_filtered = filter_to_decrease_nums(pq_years, pq_minmax_class)
pq_years_update_class, pq_update_class_filtered = filter_to_decrease_nums(pq_years, pq_update_class)
